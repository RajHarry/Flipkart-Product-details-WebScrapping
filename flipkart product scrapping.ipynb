# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("products_search.csv")
df.head()
# Out:
#                             Product Name Original_price Offer_price  \
# 0    DROGO M SS 19 Running Shoes For Men          1,899       2,699
# 1         Kray 2 M Running Shoes For Men          2,529       4,599
# 2          KYRIS M Running Shoes For Men          1,954       4,599
# 3         Kray 2 M Running Shoes For Men          2,529       4,599
# 4  HYPERON M SS 19 Running Shoes For Men          1,799       2,999
#
#   percentage   Brand  assurance  \
# 0    29% off  ADIDAS       True
# 1    45% off  ADIDAS       True
# 2    57% off  ADIDAS       True
# 3    45% off  ADIDAS       True
# 4    40% off  ADIDAS       True
#
#                                        products_link
# 0  https://www.flipkart.com/adidas-drogo-m-ss-19-...
# 1  https://www.flipkart.com/adidas-kray-2-m-runni...
# 2  https://www.flipkart.com/adidas-kyris-m-runnin...
# 3  https://www.flipkart.com/adidas-kray-2-m-runni...
# 4  https://www.flipkart.com/adidas-hyperon-m-ss-1...

# %%
df['Product Name'].value_counts()
# Out:
# Running Shoes For Men                                         11
# DROGO M SS 19 Running Shoes For Men                            4
# Mesh Running Shoes For Men                                     4
# TENNIS HASE SHOES Running Shoes For Men                        3
# ADISPREE 5.0 M SS 19 Running Shoes For Men                     3
# HYPERON M SS 19 Running Shoes For Men                          3
# WNDR-13 Running Shoes For Men                                  3
# KYRIS M Running Shoes For Men                                  2
# Quickspike MS Running Shoes For Men                            2
# Raddis 1.0 MS Running Shoes For Men                            2
# Kray 2 M Running Shoes For Men                                 2
# LITE RACER Running Shoes For Men                               2
# Duramo 8 M Running Shoes For Men                               2
# Oxygen Running Shoes For Men                                   2
# ...

# %%
df['products_link'].value_counts()
# Out:
# https://www.flipkart.com/sparx-sm-397-running-shoes-men/p/itmf8g7h4w4h7yaq?pid=SHOF8CCSZYF24RBY&lid=LSTSHOF8CCSZYF24RBYKQ3O6G&marketplace=FLIPKART&srno=s_1_8&otracker=search&otracker1=search&fm=organic&iid=29bdc704-2954-4080-aba1-c2e96e0e125c.SHOF8CCSZYF24RBY.SEARCH&ssid=yhz8s4pejk0000001568520492887&qH=fb2c617de801b9f1                                                                          1
# https://www.flipkart.com/adidas-running-shoes-men/p/itm96634b136e8f9?pid=SHOFJFXWCEZWUUQX&lid=LSTSHOFJFXWCEZWUUQXZ25P4I&marketplace=FLIPKART&srno=s_1_31&otracker=search&otracker1=search&fm=organic&iid=42abb520-68e8-446c-8b59-f2ee3ffe71ac.SHOFJFXWCEZWUUQX.SEARCH&ssid=h7tms8ez400000001568520488194&qH=47f8ba5c10136d89                                                                               1
# ...
